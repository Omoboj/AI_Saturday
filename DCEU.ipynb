# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup as bs
import re

# %% [markdown]
# ### Load the DC_Extended_Universe wiki page

# %%
page= requests.get("https://en.wikipedia.org/wiki/DC_Extended_Universe")
soup= bs(page.content)
file= soup.find("table", attrs={"wikitable plainrowheaders"})

# %% [markdown]
# ### Get list of each movie page

# %%
def get_movie_page_links(data):
    find_links= data.find_all("th", attrs={"scope":"row"})
    all_links= [link.a["href"] for link in find_links]
    return all_links

all_links_file= get_movie_page_links(file)

# %% [markdown]
# ### Get the movie titles to serve as dictionary keys

# %%
def movie_titles():
    return [movie.get_text().strip() for movie in file.find_all("th", attrs={"scope":"row"})]

titles= movie_titles()

# %% [markdown]
# ### Generate a list of table information on each movie from their respective link in the all_links_list

# %%
def get_data(link):
    page= requests.get("https://en.wikipedia.org" + link)
    soup= bs(page.content)
    file= soup.find("table", attrs={"infobox vevent"})
    return file

def load_all_data():
    return list(map(get_data, all_links_file))

movie_data= load_all_data()

# %% [markdown]
# ### Create movie attributes for a movie (from a single movie link) and map it to the links in the movie_data file

# %%
def movie_info(data):
    movie_attrs={}
    for i in data:
        try:
            movie_attrs[i.find("th").get_text()] = i.find("td").get_text().strip()         
        except AttributeError:
            pass    
    return movie_attrs

def create_movies():
    kkk= map(lambda x:movie_info(x.find_all("tr")), movie_data)
    return list(kkk)

movie_features= create_movies()

def add_year():
    movie_year= [re.search(r"\d{4}", i["Release date"]).group() for i in movie_features]
    for no in range(len(movie_features)):
        movie_features[no]["Year"] = movie_year[no]
    return movie_features

movie_features= add_year()

# %% [markdown]
# #### Access the imdb ratings by mapping a fuction to scrape the rating from a movie site and map this function with the all_rating_links_file

# %%
def rating_link(link):
    page= requests.get("https://en.wikipedia.org" + link)
    soup= bs(page.content)
    file= soup.find_all("a", attrs={"rel":"nofollow", "class":"external text"})
    for y in file:
        pattern= re.match(r"^\w+.+imdb.com.+\d/$", y["href"])
        if pattern != None:
            return(pattern.group())
        
rating_links= map(rating_link, all_links_file)

def get_imdb(link):
    page= requests.get(link)
    soup= bs(page.content)
    file= soup.find("div", attrs={"class":"ratingValue"})
    return float(file.span.get_text())

imdb_rating= list(map(get_imdb, rating_links))

# %% [markdown]
# #### Get the rotten_tomato rating by mapping the links of all the movies in the all_links_file with a function to get the rating of a single link

# %%
def get_tomatometer(link):
    page= requests.get("https://en.wikipedia.org" + link)
    soup= bs(page.content)
    file= soup.find_all("p")
    for paragraph in file:
        
        if re.search(r"\d\.\d+/10|\d/10", paragraph.text):
            result= re.search(r"\d\.\d+/10|\d/10", paragraph.text).group().replace("/10", "")
            return float(result)

tomatometer_rating= list(map(get_tomatometer, all_links_file))

# %%
def get_metacritic(link):
    page= requests.get("https://en.wikipedia.org" + link)
    soup= bs(page.content)
    file= soup.find_all("p")
    for paragraph in file:   
        if re.search(r"\d{2}\s\w{3}\s\w{2}\s100", paragraph.text):
            result= re.search(r"\d{2}\s\w{3}\s\w{2}\s100", paragraph.text).group().split(" ")[0]
            return int(result)

metacritic_rating= list(map(get_metacritic, all_links_file))

# %% [markdown]
# ### Add ratings to the movie_features

# %%
def add_ratings():
    for i in range(len(movie_features)):
        movie_features[i]["imdb rating(over 10)"]= imdb_rating[i]
        movie_features[i]["rotten tomato rating(over 10)"]= tomatometer_rating[i]
        movie_features[i]["metacritic rating(over 100)"]= metacritic_rating[i]
    return movie_features

movie_features= add_ratings()

# %% [markdown]
# ### Clean the movie_features dictionary, and extract the relevant data

# %%
def select_attrs(data):
    keep= ["Directed by","Produced by","Music by","Cinematography","Distributed by","Box office", "Year", "imdb rating(over 10)", "rotten tomato rating(over 10)", "metacritic rating(over 100)"]
    for i in data:
        for j in list(i.items()):
            if j[0] not in keep:
                i.pop(j[0])
    return data

def clean_features(data):
    for i in data:
        try:
            i["Box office"]= re.sub(r"[$\xa0]|\[\d\]$", " ", i["Box office"]).strip()
            i["Directed by"]= i["Directed by"].replace("[N 1]", "")
            i["Distributed by"]= i["Distributed by"].replace("[1]", "")
            
            if "\n" in i["Produced by"]:
                i["Produced by"]= i["Produced by"].split("\n")
            else:
                continue
        except AttributeError:
                pass    
    return data

# %%
all_features= clean_features(select_attrs(movie_features))

# %%
all_features
# Out:
# [{'Directed by': 'Zack Snyder',
#   'Produced by': ['Charles Roven',
#    'Christopher Nolan',
#    'Emma Thomas',
#    'Deborah Snyder'],
#   'Music by': 'Hans Zimmer',
#   'Cinematography': 'Amir Mokri',
#   'Distributed by': 'Warner Bros. Pictures',
#   'Box office': '668 million',
#   'Year': '2013',
#   'imdb rating(over 10)': 7.0,
#   'rotten tomato rating(over 10)': 6.2,
#   'metacritic rating(over 100)': 55},
#  {'Directed by': 'Zack Snyder',
#   'Produced by': ['Charles Roven', 'Deborah Snyder'],
#   'Music by': 'Hans Zimmer\nJunkie XL',
#   'Cinematography': 'Larry Fong',
#   'Distributed by': 'Warner Bros. Pictures',
#   'Box office': '873.6 million',
#   'Year': '2016',
#   'imdb rating(over 10)': 6.4,
#   'rotten tomato rating(over 10)': 5.0,
#   'metacritic rating(over 100)': 44},
#  {'Directed by': 'David Ayer',
#   'Produced by': ['Charles Roven', 'Richard Suckle'],
#   'Music by': 'Steven Price',
#   'Cinematography': 'Roman Vasyanov',
#   'Distributed by': 'Warner Bros. Pictures',
#   'Box office': '746.8 million',
#   'Year': '2016',
#   'imdb rating(over 10)': 6.0,
#   'rotten tomato rating(over 10)': 4.78,
#   'metacritic rating(over 100)': 40},
#  {'Directed by': 'Patty Jenkins',
#   'Produced by': ['Charles Roven',
#    'Deborah Snyder',
#    'Zack Snyder',
#    'Richard Suckle'],
#   'Music by': 'Rupert Gregson-Williams',
#   'Cinematography': 'Matthew Jensen',
#   'Distributed by': 'Warner Bros. Pictures',
#   'Box office': '822.3 million',
#   'Year': '2017',
#   'imdb rating(over 10)': 7.4,
#   'rotten tomato rating(over 10)': 7.7,
#   'metacritic rating(over 100)': 76},
#  {'Directed by': 'Zack Snyder',
#   'Produced by': ['Charles Roven',
#    'Deborah Snyder',
#    'Jon Berg',
#    'Geoff Johns'],
#   'Music by': 'Danny Elfman',
#   'Cinematography': 'Fabian Wagner',
#   'Distributed by': 'Warner Bros. Pictures',
#   'Box office': '657.9 million',
#   'Year': '2017',
#   'imdb rating(over 10)': 6.3,
#   'rotten tomato rating(over 10)': 5.3,
#   'metacritic rating(over 100)': 45},
#  {'Directed by': 'James Wan',
#   'Produced by': ['Peter Safran', 'Rob Cowan'],
#   'Music by': 'Rupert Gregson-Williams',
#   'Cinematography': 'Don Burgess',
#   'Distributed by': 'Warner Bros. Pictures',
#   'Box office': '1.148 billion',
#   'Year': '2018',
#   'imdb rating(over 10)': 6.9,
#   'rotten tomato rating(over 10)': 6.0,
#   'metacritic rating(over 100)': 55},
#  {'Directed by': 'David F. Sandberg',
#   'Produced by': 'Peter Safran',
#   'Music by': 'Benjamin Wallfisch',
#   'Cinematography': 'Maxime Alexandre',
#   'Distributed by': 'Warner Bros. Pictures',
#   'Box office': '366 million',
#   'Year': '2019',
#   'imdb rating(over 10)': 7.0,
#   'rotten tomato rating(over 10)': 7.3,
#   'metacritic rating(over 100)': 71},
#  {'Directed by': 'Cathy Yan',
#   'Produced by': ['Margot Robbie', 'Bryan Unkeless', 'Sue Kroll'],
#   'Music by': 'Daniel Pemberton',
#   'Cinematography': 'Matthew Libatique',
#   'Distributed by': 'Warner Bros. Pictures',
#   'Box office': '201.8 million',
#   'Year': '2020',
#   'imdb rating(over 10)': 6.1,
#   'rotten tomato rating(over 10)': 6.8,
#   'metacritic rating(over 100)': 60},
#  {'Directed by': 'Patty Jenkins',
#   'Produced by': ['Charles Roven',
#    'Deborah Snyder',
#    'Zack Snyder',
#    'Patty Jenkins',
#    'Gal Gadot',
#    'Stephen Jones'],
#   'Music by': 'Hans Zimmer',
#   'Cinematography': 'Matthew Jensen',
#   'Distributed by': 'Warner Bros. Pictures',
#   'Box office': '152.2 million',
#   'Year': '2020',
#   'imdb rating(over 10)': 5.4,
#   'rotten tomato rating(over 10)': 6.1,
#   'metacritic rating(over 100)': 60}]

# %% [markdown]
# ### Create a dictionary of individual movies and pair them with their respective movie_features

# %%
def movies_dict():
    folder={}
    for i in range(len(all_features)):
        folder[titles[i]] = movie_features[i]
    return folder

all_dc_movies= movies_dict()

# %%
all_dc_movies
# Out:
# {'Man of Steel': {'Directed by': 'Zack Snyder',
#   'Produced by': ['Charles Roven',
#    'Christopher Nolan',
#    'Emma Thomas',
#    'Deborah Snyder'],
#   'Music by': 'Hans Zimmer',
#   'Cinematography': 'Amir Mokri',
#   'Distributed by': 'Warner Bros. Pictures',
#   'Box office': '668 million',
#   'Year': '2013',
#   'imdb rating(over 10)': 7.0,
#   'rotten tomato rating(over 10)': 6.2,
#   'metacritic rating(over 100)': 55},
#  'Batman v Superman: Dawn of Justice': {'Directed by': 'Zack Snyder',
#   'Produced by': ['Charles Roven', 'Deborah Snyder'],
#   'Music by': 'Hans Zimmer\nJunkie XL',
#   'Cinematography': 'Larry Fong',
#   'Distributed by': 'Warner Bros. Pictures',
#   'Box office': '873.6 million',
#   'Year': '2016',
#   'imdb rating(over 10)': 6.4,
#   'rotten tomato rating(over 10)': 5.0,
#   'metacritic rating(over 100)': 44},
#  'Suicide Squad': {'Directed by': 'David Ayer',
#   'Produced by': ['Charles Roven', 'Richard Suckle'],
#   'Music by': 'Steven Price',
#   'Cinematography': 'Roman Vasyanov',
#   'Distributed by': 'Warner Bros. Pictures',
#   'Box office': '746.8 million',
#   'Year': '2016',
#   'imdb rating(over 10)': 6.0,
#   'rotten tomato rating(over 10)': 4.78,
#   'metacritic rating(over 100)': 40},
#  'Wonder Woman': {'Directed by': 'Patty Jenkins',
#   'Produced by': ['Charles Roven',
#    'Deborah Snyder',
#    'Zack Snyder',
#    'Richard Suckle'],
#   'Music by': 'Rupert Gregson-Williams',
#   'Cinematography': 'Matthew Jensen',
#   'Distributed by': 'Warner Bros. Pictures',
#   'Box office': '822.3 million',
#   'Year': '2017',
#   'imdb rating(over 10)': 7.4,
#   'rotten tomato rating(over 10)': 7.7,
#   'metacritic rating(over 100)': 76},
#  'Justice League': {'Directed by': 'Zack Snyder',
#   'Produced by': ['Charles Roven',
#    'Deborah Snyder',
#    'Jon Berg',
#    'Geoff Johns'],
#   'Music by': 'Danny Elfman',
#   'Cinematography': 'Fabian Wagner',
#   'Distributed by': 'Warner Bros. Pictures',
#   'Box office': '657.9 million',
#   'Year': '2017',
#   'imdb rating(over 10)': 6.3,
#   'rotten tomato rating(over 10)': 5.3,
#   'metacritic rating(over 100)': 45},
#  'Aquaman': {'Directed by': 'James Wan',
#   'Produced by': ['Peter Safran', 'Rob Cowan'],
#   'Music by': 'Rupert Gregson-Williams',
#   'Cinematography': 'Don Burgess',
#   'Distributed by': 'Warner Bros. Pictures',
#   'Box office': '1.148 billion',
#   'Year': '2018',
#   'imdb rating(over 10)': 6.9,
#   'rotten tomato rating(over 10)': 6.0,
#   'metacritic rating(over 100)': 55},
#  'Shazam!': {'Directed by': 'David F. Sandberg',
#   'Produced by': 'Peter Safran',
#   'Music by': 'Benjamin Wallfisch',
#   'Cinematography': 'Maxime Alexandre',
#   'Distributed by': 'Warner Bros. Pictures',
#   'Box office': '366 million',
#   'Year': '2019',
#   'imdb rating(over 10)': 7.0,
#   'rotten tomato rating(over 10)': 7.3,
#   'metacritic rating(over 100)': 71},
#  'Birds of Prey': {'Directed by': 'Cathy Yan',
#   'Produced by': ['Margot Robbie', 'Bryan Unkeless', 'Sue Kroll'],
#   'Music by': 'Daniel Pemberton',
#   'Cinematography': 'Matthew Libatique',
#   'Distributed by': 'Warner Bros. Pictures',
#   'Box office': '201.8 million[3]',
#   'Year': '2020',
#   'imdb rating(over 10)': 6.1,
#   'rotten tomato rating(over 10)': 6.8,
#   'metacritic rating(over 100)': 60},
#  'Wonder Woman 1984': {'Directed by': 'Patty Jenkins',
#   'Produced by': ['Charles Roven',
#    'Deborah Snyder',
#    'Zack Snyder',
#    'Patty Jenkins',
#    'Gal Gadot',
#    'Stephen Jones'],
#   'Music by': 'Hans Zimmer',
#   'Cinematography': 'Matthew Jensen',
#   'Distributed by': 'Warner Bros. Pictures',
#   'Box office': '152.2 million[4]',
#   'Year': '2020',
#   'imdb rating(over 10)': 5.4,
#   'rotten tomato rating(over 10)': 6.1,
#   'metacritic rating(over 100)': 60}}

# %%
def frame(data):
    df= pd.DataFrame(data.values(), index= data.keys())
    new=[]
    for i in df["Box office"]:
        action= i.split(" ")
        if action[1]=="million":
            new.append((float(action[0])/1000))
        elif action[1]=="billion":
            new.append(float(action[0]))
    df["Box office (billion $$)"] = new
    df.drop("Box office", axis=1, inplace=True)
    return df

dc_df= frame(all_dc_movies)

# %%
dc_df
# Out:
#                                           Directed by  \
# Man of Steel                              Zack Snyder
# Batman v Superman: Dawn of Justice        Zack Snyder
# Suicide Squad                              David Ayer
# Wonder Woman                            Patty Jenkins
# Justice League                            Zack Snyder
# Aquaman                                     James Wan
# Shazam!                             David F. Sandberg
# Birds of Prey                               Cathy Yan
# Wonder Woman 1984                       Patty Jenkins
#
#                                                                           Produced by  \
# Man of Steel                        [Charles Roven, Christopher Nolan, Emma Thomas...
# Batman v Superman: Dawn of Justice                    [Charles Roven, Deborah Snyder]
# Suicide Squad                                         [Charles Roven, Richard Suckle]
# Wonder Woman                        [Charles Roven, Deborah Snyder, Zack Snyder, R...
# Justice League                      [Charles Roven, Deborah Snyder, Jon Berg, Geof...
# Aquaman                                                     [Peter Safran, Rob Cowan]
# Shazam!                                                                  Peter Safran
# Birds of Prey                              [Margot Robbie, Bryan Unkeless, Sue Kroll]
# Wonder Woman 1984                   [Charles Roven, Deborah Snyder, Zack Snyder, P...
#
#                                                    Music by  \
# Man of Steel                                    Hans Zimmer
# Batman v Superman: Dawn of Justice   Hans Zimmer\nJunkie XL
# Suicide Squad                                  Steven Price
# Wonder Woman                        Rupert Gregson-Williams
# Justice League                                 Danny Elfman
# Aquaman                             Rupert Gregson-Williams
# Shazam!                                  Benjamin Wallfisch
# Birds of Prey                              Daniel Pemberton
# Wonder Woman 1984                               Hans Zimmer
#
#                                        Cinematography         Distributed by  \
# Man of Steel                               Amir Mokri  Warner Bros. Pictures
# Batman v Superman: Dawn of Justice         Larry Fong  Warner Bros. Pictures
# Suicide Squad                          Roman Vasyanov  Warner Bros. Pictures
# Wonder Woman                           Matthew Jensen  Warner Bros. Pictures
# Justice League                          Fabian Wagner  Warner Bros. Pictures
# Aquaman                                   Don Burgess  Warner Bros. Pictures
# Shazam!                              Maxime Alexandre  Warner Bros. Pictures
# Birds of Prey                       Matthew Libatique  Warner Bros. Pictures
# Wonder Woman 1984                      Matthew Jensen  Warner Bros. Pictures
#
#                                     Year  imdb rating(over 10)  \
# Man of Steel                        2013                   7.0
# Batman v Superman: Dawn of Justice  2016                   6.4
# Suicide Squad                       2016                   6.0
# Wonder Woman                        2017                   7.4
# Justice League                      2017                   6.3
# Aquaman                             2018                   6.9
# Shazam!                             2019                   7.0
# Birds of Prey                       2020                   6.1
# Wonder Woman 1984                   2020                   5.4
#
#                                     rotten tomato rating(over 10)  \
# Man of Steel                                                 6.20
# Batman v Superman: Dawn of Justice                           5.00
# Suicide Squad                                                4.78
# Wonder Woman                                                 7.70
# Justice League                                               5.30
# Aquaman                                                      6.00
# Shazam!                                                      7.30
# Birds of Prey                                                6.80
# Wonder Woman 1984                                            6.10
#
#                                     metacritic rating(over 100)  \
# Man of Steel                                                 55
# Batman v Superman: Dawn of Justice                           44
# Suicide Squad                                                40
# Wonder Woman                                                 76
# Justice League                                               45
# Aquaman                                                      55
# Shazam!                                                      71
# Birds of Prey                                                60
# Wonder Woman 1984                                            60
#
#                                     Box office (billion $$)
# Man of Steel                                         0.6680
# Batman v Superman: Dawn of Justice                   0.8736
# Suicide Squad                                        0.7468
# Wonder Woman                                         0.8223
# Justice League                                       0.6579
# Aquaman                                              1.1480
# Shazam!                                              0.3660
# Birds of Prey                                        0.2018
# Wonder Woman 1984                                    0.1522

# %%
dc_df["Universe"]= "DC"

# %%
dc_df.to_csv(r"C:\Users\hp\AI_Saturdays\Marvel_VS_DC_project\AI_Saturday\dc_df.csv")
